# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# *** Include the name of your folder:

# %%
import os
#HOME = os.getcwd()
HOME = '/content/drive/MyDrive/"your folder name"/'
print(HOME)
# %cd {HOME}
# !ls
# Out:
# /content/drive/MyDrive/WSprueba/
# /content/drive/MyDrive/WSprueba
# datasets  Raor-autor-Josep-Alos-Mallorca.jpg  weights_baited  yolov8x.pt
# imgres	  runs				      yolov8m.pt      yolov8x-seg.pt

# %%
# Pip install method (recommended)

# !pip install ultralytics #==8.0.28

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.15 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.7/107.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd {HOME}
# Out:
# /content/drive/MyDrive/WSprueba

# %% [markdown]
# # ***  Let's use YOUR trained MODEL:
#
# (check if it is saved at train, train1, train2...)

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.5 source=https://www.masmallorca.es/wp-content/uploads/2018/08/Raor-autor-Josep-Alos-Mallorca.jpg save=True hide_conf=False imgsz=250
# Out:
# WARNING ⚠️ 'hide_conf' is deprecated and will be removed in 'ultralytics 8.299999999999999' in the future. Please use 'show_conf' instead.
# Ultralytics YOLOv8.1.15 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 268 layers, 68124531 parameters, 0 gradients, 257.4 GFLOPs
#
# WARNING ⚠️ imgsz=[250] must be multiple of max stride 32, updating to [256]
# Found https://www.masmallorca.es/wp-content/uploads/2018/08/Raor-autor-Josep-Alos-Mallorca.jpg locally at Raor-autor-Josep-Alos-Mallorca.jpg
# image 1/1 /content/drive/MyDrive/WSprueba/Raor-autor-Josep-Alos-Mallorca.jpg: 160x256 (no detections), 567.3ms
# Speed: 1.8ms preprocess, 567.3ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 256)
# Results saved to runs/detect/predict10
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# *** Let's visualized it:
#
# (check if the predict images are in predict, predict1, predict2...)

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/detect/predict/*.jpg')[:]:
      display(Image(filename=image_path, height=300))
      print("\n")

# %% [markdown]
# # *** Let's use YOLO MODEL:
#
# (try with different versions)

# %%
# !yolo task=detect mode=predict model={HOME}/yolov8x.pt conf=0.1 source=https://www.masmallorca.es/wp-content/uploads/2018/08/Raor-autor-Josep-Alos-Mallorca.jpg
# Out:
# Ultralytics YOLOv8.1.15 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8x summary (fused): 268 layers, 68200608 parameters, 0 gradients, 257.8 GFLOPs
#
# Found https://www.masmallorca.es/wp-content/uploads/2018/08/Raor-autor-Josep-Alos-Mallorca.jpg locally at Raor-autor-Josep-Alos-Mallorca.jpg
# image 1/1 /content/drive/MyDrive/WSprueba/Raor-autor-Josep-Alos-Mallorca.jpg: 416x640 1 bird, 1 sports ball, 2727.1ms
# Speed: 3.9ms preprocess, 2727.1ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs/detect/predict11
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# *** Let's visualized it:
#
# (check the predict folder)

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/detect/predict/*.jpg')[:]:
      display(Image(filename=image_path, height=300))
      print("\n")

# %% [markdown]
# # *** Let's use a trained MODEL:
#
# (change confidence score number)

# %%
# !yolo task=detect mode=predict model={HOME}/weights_baited/best.pt conf=0.8 source=https://www.masmallorca.es/wp-content/uploads/2018/08/Raor-autor-Josep-Alos-Mallorca.jpg
# Out:
# Ultralytics YOLOv8.1.15 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 218 layers, 25843813 parameters, 0 gradients, 78.7 GFLOPs
#
# Found https://www.masmallorca.es/wp-content/uploads/2018/08/Raor-autor-Josep-Alos-Mallorca.jpg locally at Raor-autor-Josep-Alos-Mallorca.jpg
# image 1/1 /content/drive/MyDrive/WSprueba/Raor-autor-Josep-Alos-Mallorca.jpg: 416x640 1 raor, 1013.3ms
# Speed: 7.3ms preprocess, 1013.3ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs/detect/predict12
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
*** Let's visualized it:

(again, take into account the folder name)

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/detect/predict/*.jpg')[:]:
      display(Image(filename=image_path, height=300))
      print("\n")
