# %% [markdown]
# **Colab Notebook obtained from ROBOFLOW notebook examples.**

# %% [markdown]
# **Mount your google drive:**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# If you want to **save** the database and the model, create a folder at your drive.

# %%
import os
#HOME = os.getcwd()
HOME = '/content/drive/MyDrive/WORKSHOP_AI/'
print(HOME)
# %cd {HOME}
# !ls
# Out:
# /content/drive/MyDrive/WORKSHOP_AI/
# [Errno 2] No such file or directory: '/content/drive/MyDrive/WORKSHOP_AI/'
# /content
# sample_data

# %% [markdown]
# **Install the libraries.**

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.28

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# **Create a folder to save the datasets.**

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets
# !ls
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/WORKSHOP_AI//datasets’: File exists
# /content/drive/MyDrive/WORKSHOP_AI/datasets

# %%
print(os.path.abspath(HOME))
#print(os.path.abspath(dataset))
# Out:
# /content/drive/MyDrive/WORKSHOP_AI

# %% [markdown]
# **Upload the Roboflow dataset to be trained.**

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="f0fitlMNHckrUKBnoP8n")
project = rf.workspace("arancha-lana").project("mero-segmentation")
dataset = project.version(2).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 17.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 20.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 13.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
# ...

# %%
dataset.location
# Out:
# '/content/drive/MyDrive/WORKSHOP_AI/mero-segmentation-2'

# %% [markdown]
# **TRAIN your model.**

# %%
# %cd {HOME}

# !yolo task=segment mode=train model=yolov8x-seg.pt data={dataset.location}/data.yaml epochs=10 imgsz=250
# Out:
# /content/drive/MyDrive/WORKSHOP_AI
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
